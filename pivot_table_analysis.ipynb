# %%
import pandas as pd

# Sample Sales Data
data = {
    'Date': ['2025-03-01', '2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05'],
    'Region': ['East', 'West', 'North', 'South', 'East'],
    'Product': ['Laptop', 'Tablet', 'Phone', 'Laptop', 'Phone'],
    'Sales': [1200, 800, 1500, 1000, 700]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('sales_data.csv', index=False)

print("Sample dataset created as 'sales_data.csv'. Now you can proceed with the analysis.")
# Out:
# Sample dataset created as 'sales_data.csv'. Now you can proceed with the analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset (replace with your file path)
data = pd.read_csv('sales_data.csv')

# Display first few rows
display(data.head())

# Create a Pivot Table to analyze sales by Region and Product
#pivot_table = pd.pivot_table(data, values='Sales', index='Region', columns='Product', aggfunc=np.sum, fill_value=0)
pivot_table = pd.pivot_table(data, values='Sales', index='Region', columns='Product', aggfunc="sum", fill_value=0)
display(pivot_table)



# Visualization - Sales by Region and Product
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='Blues', fmt='.0f')
plt.title('Sales by Region and Product')
plt.show()

# Save Pivot Table to CSV
pivot_table.to_csv('pivot_table_output.csv')

print("Pivot table analysis completed and saved.")
# Out:
#          Date Region Product  Sales
# 0  2025-03-01   East  Laptop   1200
# 1  2025-03-02   West  Tablet    800
# 2  2025-03-03  North   Phone   1500
# 3  2025-03-04  South  Laptop   1000
# 4  2025-03-05   East   Phone    700
# Product  Laptop  Phone  Tablet
# Region
# East       1200    700       0
# North         0   1500       0
# South      1000      0       0
# West          0      0     800
# Pivot table analysis completed and saved.
